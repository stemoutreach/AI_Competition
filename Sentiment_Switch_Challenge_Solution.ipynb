# %% [markdown]
# ---
#
# ## 🧮 Challenge 2: Sentiment Switch – Retarget a Text Classifier
#
# **Scenario:**
# You’ve inherited a sentiment classifier trained on movie reviews, but your team needs it to analyze product reviews. Your job is to curate a small training set and evaluate performance before and after adaptation.
#
# **Notebook Steps:**
# 1. Load product review data and inspect samples.
# 2. Run several reviews through the existing model to evaluate fit.
# 3. Select 5–10 balanced examples for fine-tuning.
# 4. (Optional) Apply model adaptation using the sample function.
#
# **Deliverables:**
# - Labeled product review samples
# - Comparison of model predictions before/after adaptation
# - Explanation of adaptation decisions and impact on task relevance

# %% [markdown]
# # 🧮 Sentiment Switch: Retarget a Text Classifier
# Here, we adapt a sentiment classifier trained on movies to classify product reviews.

# %%
import pandas as pd

df = pd.read_csv('product_reviews.csv')
df.head()

# %% [markdown]
# ### 🔍 Sample Prompt Testing
# Run some example reviews through the existing model to test performance.

# %%
# from transformers import pipeline
# sentiment_model = pipeline('sentiment-analysis')
# examples = df['text'].sample(3).tolist()
# for review in examples:
#     print(review)
#     print(sentiment_model(review))

# %% [markdown]
# ---## 🧮 Challenge 2: Sentiment Switch – Retarget a Text Classifier**Scenario:**  You’ve inherited a sentiment classifier trained on movie reviews, but your team needs it to analyze product reviews. Your job is to curate a small training set and evaluate performance before and after adaptation.**Notebook Steps:**  1. Load product review data and inspect samples.  2. Run several reviews through the existing model to evaluate fit.  3. Select 5–10 balanced examples for fine-tuning.  4. (Optional) Apply model adaptation using the sample function.**Deliverables:**  - Labeled product review samples  - Comparison of model predictions before/after adaptation  - Explanation of adaptation decisions and impact on task relevance
